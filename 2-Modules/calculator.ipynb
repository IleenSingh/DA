# %%
#Custom package ko use krenge 
#method 1
from package.maths import addition
addition(4,9)
# Out:
# 13

# %%
#method 2
from package import maths
maths.addition(10,12)
# Out:
# 22

# %% [markdown]
# ### more functions

# %%
from package import maths
print(maths.subtraction(120,22))
print(maths.division(120,10))
print(maths.multiply(12,5))
# Out:
# 98
# 12.0
# 60
