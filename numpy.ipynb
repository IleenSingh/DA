# %% [markdown]
# ### numpy

# %%
import numpy as np

#creating array using numpy
arr = np.array([1,2,3,4,5])
arr2 = np.array([[1,2] ,[3,4]])
print(arr)
print(arr2)
print(type(arr))
print(type(arr2))
print(arr.shape)
print(arr2.shape)

#shape agar ek number aaya means 1-D array h or agar do toh 2-D array hai
# Out:
# [1 2 3 4 5]
# [[1 2]
#  [3 4]]
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# (5,)
# (2, 2)
