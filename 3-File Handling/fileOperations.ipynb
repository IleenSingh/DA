# %% [markdown]
# ### how to read a whole file

# %%
with open('example.txt' ,"r") as file:
    content =file.read()
    print(content)
# Out:
# Example fiiiiiiiiillllllllleeeeeeeeeee
# Checking file 1223334444.......
